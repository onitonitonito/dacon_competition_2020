# %% [markdown]
# | <img src ='https://bit.ly/39XPeCc' width=200 align='left'> |
# |:--|
# |<h1>   Random_forest_xtrain_xtest_final.ipynb
# </h1>

# %% [markdown]
# ## 사용함수의 정의

# %%
""" 
# 기본적인 module import 위치로 작업폴더 변경 getcwd() --> chidr()
# HOME 을 지정하고 작업폴더를 HOME 으로 변경.
"""
import os

HOME= 'dacon_competition_2020'
dir_base = "".join(os.getcwd().partition(HOME)[:2]) + "\\"
os.chdir(dir_base)

# %%
from _assets.config_dirs import *
from _assets.modules import *
# Out:
# # 화일분석에 필요한 공동폴더를 등록합니다.
# - asset = dir_base + '_assets/'
# - statics dir_base + '_statics/'
#
# #  echo = True : SYS.PATH INSERT 상황 보여줌
#
#
# # OS 화일 및 DF 정보조회를 위한 탐색 모듈

# %%
"""
# RandomForestClassifier 클래스를 import
"""
import numpy as np
import pandas as pd
 
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
x = pd.read_csv(dir_base + remake + 'df_xtrain_remake_final.csv')
y = pd.read_csv(dir_base + remake + 'df_ytrain_remake.csv')['winner']

X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.2)

# %%
show_infoDF_from(x)
# Out:
# *** DATA SHAPE = [ 38,872 x 42 ]
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38872 entries, 0 to 38871
# Data columns (total 42 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   game_id                  38872 non-null  int64
#  1   game_id.1                38872 non-null  int64
#  2   time_spend               38872 non-null  float64
#  3   P0_species               38872 non-null  int64
#  4   P0_Ability               38872 non-null  float64
#  5   P0_AddToControlGroup     38872 non-null  float64
#  6   P0_Camera                38872 non-null  float64
#  7   P0_ControlGroup          38872 non-null  float64
#  8   P0_GetControlGroup       38872 non-null  float64
#  9   P0_Right Click           38872 non-null  float64
#  10  P0_Selection             38872 non-null  float64
#  11  P0_SetControlGroup       38872 non-null  float64
#  12  P1_species               38872 non-null  int64
#  13  P1_Ability               38872 non-null  float64
#  14  P1_AddToControlGroup     38872 non-null  float64
#  15  P1_Camera                38872 non-null  float64
#  16  P1_ControlGroup          38872 non-null  float64
#  17  P1_GetControlGroup       38872 non-null  float64
#  18  P1_Right Click           38872 non-null  float64
#  19  P1_Selection             38872 non-null  float64
#  20  P1_SetControlGroup       38872 non-null  float64
#  21  delta_Ability            38872 non-null  float64
#  22  delta_AddToControlGroup  38872 non-null  float64
#  23  delta_Camera             38872 non-null  float64
#  24  delta_ControlGroup       38872 non-null  float64
#  25  delta_GetControlGroup    38872 non-null  float64
#  26  delta_Right Click        38872 non-null  float64
#  27  delta_Selection          38872 non-null  float64
#  28  delta_SetControlGroup    38872 non-null  float64
#  29  p0_null                  38872 non-null  float64
#  30  p1_null                  38872 non-null  float64
#  31  delta_null               38872 non-null  float64
#  32  p0_train                 38872 non-null  float64
#  33  p1_train                 38872 non-null  float64
#  34  delta_train              38872 non-null  float64
#  35  p0_attack                38872 non-null  float64
#  36  p1_attack                38872 non-null  float64
#  37  delta_attack             38872 non-null  float64
#  38  p0_select_null           38872 non-null  float64
#  39  p1_select_null           38872 non-null  float64
#  40  delta_select_null        38872 non-null  float64
#  41  p0_weight                38872 non-null  float64
# dtypes: float64(38), int64(4)
# memory usage: 12.5 MB
# None
#
#             game_id     game_id.1    time_spend    P0_species    P0_Ability  \
# count  38872.000000  38872.000000  38872.000000  38872.000000  38872.000000
# mean   19435.500000  19435.500000      7.289366      0.943790     48.806467
# std    11221.524169  11221.524169      2.590104      0.846693     28.119083
# min        0.000000      0.000000      0.080000      0.000000      0.000000
# 25%     9717.750000   9717.750000      5.270000      0.000000     27.000000
# 50%    19435.500000  19435.500000      8.140000      1.000000     46.000000
# 75%    29153.250000  29153.250000      9.590000      2.000000     66.000000
# max    38871.000000  38871.000000     10.590000      2.000000    216.000000
#
#        P0_AddToControlGroup     P0_Camera  P0_ControlGroup  \
# count          38872.000000  38872.000000     38872.000000
# mean               1.918450    407.357918         0.396275
# std                3.038626    222.351156         3.431973
# min                0.000000      0.000000         0.000000
# 25%                0.000000    238.000000         0.000000
# 50%                0.000000    390.000000         0.000000
# 75%                3.000000    549.000000         0.000000
# max               35.000000   1832.000000       241.000000
#
#        P0_GetControlGroup  P0_Right Click  ...      p0_train      p1_train  \
# count        38872.000000    38872.000000  ...  38872.000000  38872.000000
# mean           129.523307      148.942118  ...     18.852979     18.792910
# std            186.127982       97.965154  ...      9.995029      9.945299
# min              0.000000        0.000000  ...      0.000000      0.000000
# 25%             11.000000       71.000000  ...     11.000000     11.000000
# 50%             45.000000      133.000000  ...     18.000000     18.000000
# 75%            175.000000      210.000000  ...     25.000000     25.000000
# max           2320.000000      856.000000  ...     79.000000     71.000000
#
#         delta_train     p0_attack     p1_attack  delta_attack  p0_select_null  \
# count  38872.000000  38872.000000  38872.000000  38872.000000    38872.000000
# mean       0.060069      7.321954      7.370138     -0.048184       10.483407
# std        7.890922      9.100631      9.121453      9.000866       11.532427
# min      -47.000000      0.000000      0.000000    -78.000000        0.000000
# 25%       -4.000000      1.000000      1.000000     -3.000000        2.000000
# 50%        0.000000      4.000000      4.000000      0.000000        7.000000
# 75%        4.000000     11.000000     11.000000      3.000000       15.000000
# max       48.000000    132.000000    100.000000    110.000000      185.000000
#
#        p1_select_null  delta_select_null     p0_weight
# count    38872.000000       38872.000000  38872.000000
# mean        10.399799           0.083608      2.839466
# std         11.337223          12.904326      2.397724
# min          0.000000        -166.000000      0.308154
# 25%          2.000000          -5.000000      0.308154
# 50%          7.000000           0.000000      2.459397
# 75%         15.000000           5.000000      4.000000
# max        176.000000         179.000000     12.888889
#
# [8 rows x 42 columns]

# %%
"""
# tree개수 Random Forest 분류 모듈 생성
# 그냥 Default 값을 사용한다.
# 차이점 = 정렬된 Data 사용 <==> shuffled data-set 사용
"""
rfc = RandomForestClassifier(          # default = *                    
                    bootstrap=True,    # 붓스트랩 생성*
                    criterion='gini',  # 지니계수 검정*
                    max_features='auto', # 최대피처=자동*
    
                    n_estimators=400,  # 트리갯수=400개
                    oob_score=True,    # OOB스코링 사용!
                    verbose=1,         # 상세하게 에코!
                    warm_start=True,   # 웜스타트=OK
                )

# %%
"""
# X_train과 Y_train을 입력해 모듈을 학습 시킨다.
"""

rfc.fit(X_train, Y_train) 
pred = rfc.predict(X_test)

# print(pred == Y_test)
print("Accuracy is: ", accuracy_score(pred, Y_test))
print("----" * 20)
print(classification_report(pred, Y_test))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:  1.4min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Accuracy is:  0.6028295819935692
# --------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.61      0.60      0.61      3966
#            1       0.59      0.61      0.60      3809
#
#     accuracy                           0.60      7775
#    macro avg       0.60      0.60      0.60      7775
# weighted avg       0.60      0.60      0.60      7775
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    1.5s finished

# %%
"""
# Initialize the model
# 트리수=200개, OOB 스코어링을 사용한다.
"""
rfc_01 = RandomForestClassifier(             # default = *                    
                            bootstrap=True,  # 붓스트랩 생성*
                            criterion='gini', # 지니계수 검정*
    
                            max_features=5,   # Num features = 5
                            n_estimators=600, # Number of trees = 600개
                            oob_score=True,  # Use OOB scoring
                            verbose=1,       # 상세하게 에코!
                        )

# %%
rfc_01.fit(X_train, Y_train)
pred_01 = rfc_01.predict(X_test)

# print(pred_01 == Y_test)
print("Accuracy is : ", accuracy_score(pred_01, Y_test))
print("----" * 20)
print(classification_report(pred_01, Y_test))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 600 out of 600 | elapsed:  1.8min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Accuracy is :  0.6
# --------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60      3916
#            1       0.60      0.60      0.60      3859
#
#     accuracy                           0.60      7775
#    macro avg       0.60      0.60      0.60      7775
# weighted avg       0.60      0.60      0.60      7775
# [Parallel(n_jobs=1)]: Done 600 out of 600 | elapsed:    2.3s finished

# %%
"""
# 각 feature의 중요도를 확인 한다.
"""

for feature, imp in zip(x.columns, rfc_01.feature_importances_):
    print(f"* {feature:18} = {imp}")
# Out:
# * game_id            = 0.031218671163962364
# * game_id.1          = 0.031187640107181665
# * time_spend         = 0.02734358296198139
# * P0_species         = 0.0076195686497766
# * P0_Ability         = 0.028421227108117293
# * P0_AddToControlGroup = 0.012681034594101763
# * P0_Camera          = 0.03316122426932528
# * P0_ControlGroup    = 0.002716395852877583
# * P0_GetControlGroup = 0.026706017990049447
# * P0_Right Click     = 0.03111998437224187
# * P0_Selection       = 0.03159053757320755
# * P0_SetControlGroup = 0.017901957398354585
# * P1_species         = 0.007699737113084685
# * P1_Ability         = 0.029112222371783545
# * P1_AddToControlGroup = 0.012551189483575533
# * P1_Camera          = 0.03294225187105283
# * P1_ControlGroup    = 0.002775328334781732
# * P1_GetControlGroup = 0.02583032966342668
# * P1_Right Click     = 0.031492616997362124
# * P1_Selection       = 0.031103260521853113
# * P1_SetControlGroup = 0.017859105607065204
# * delta_Ability      = 0.04378550567634032
# * delta_AddToControlGroup = 0.018813347348093926
# * delta_Camera       = 0.03303976752299002
# * delta_ControlGroup = 0.005229496240886458
# * delta_GetControlGroup = 0.030428502543000575
# * delta_Right Click  = 0.032722820627319314
# * delta_Selection    = 0.03235337180774547
# * delta_SetControlGroup = 0.022241671997226656
# * p0_null            = 0.027377115475304296
# * p1_null            = 0.026521386973213438
# * delta_null         = 0.03182702251487968
# * p0_train           = 0.0239878112195128
# * p1_train           = 0.023861527885816292
# * delta_train        = 0.029442853660463852
# * p0_attack          = 0.01909387829725599
# * p1_attack          = 0.018965430053012294
# * delta_attack       = 0.02312959446489789
# * p0_select_null     = 0.02216347165616962
# * p1_select_null     = 0.02214680196653245
# * delta_select_null  = 0.025673091174902338
# * p0_weight          = 0.014161646889273474

# %%
pd.DataFrame(
            zip(x.columns,rfc_01.feature_importances_), 
            columns=['features', 'importance']
        ).sort_values(
                    by='importance', 
                    ascending=False,
                )
# Out:
#                    features  importance
# 21            delta_Ability    0.043786
# 6                 P0_Camera    0.033161
# 23             delta_Camera    0.033040
# 15                P1_Camera    0.032942
# 26        delta_Right Click    0.032723
# 27          delta_Selection    0.032353
# 31               delta_null    0.031827
# 10             P0_Selection    0.031591
# 18           P1_Right Click    0.031493
# 0                   game_id    0.031219
# 1                 game_id.1    0.031188
# 9            P0_Right Click    0.031120
# 19             P1_Selection    0.031103
# 25    delta_GetControlGroup    0.030429
# 34              delta_train    0.029443
# 13               P1_Ability    0.029112
# 4                P0_Ability    0.028421
# 29                  p0_null    0.027377
# 2                time_spend    0.027344
# 8        P0_GetControlGroup    0.026706
# 30                  p1_null    0.026521
# 17       P1_GetControlGroup    0.025830
# 40        delta_select_null    0.025673
# 32                 p0_train    0.023988
# 33                 p1_train    0.023862
# 37             delta_attack    0.023130
# 28    delta_SetControlGroup    0.022242
# 38           p0_select_null    0.022163
# 39           p1_select_null    0.022147
# 35                p0_attack    0.019094
# 36                p1_attack    0.018965
# 22  delta_AddToControlGroup    0.018813
# 11       P0_SetControlGroup    0.017902
# 20       P1_SetControlGroup    0.017859
# 41                p0_weight    0.014162
# 5      P0_AddToControlGroup    0.012681
# 14     P1_AddToControlGroup    0.012551
# 12               P1_species    0.007700
# 3                P0_species    0.007620
# 24       delta_ControlGroup    0.005229
# 16          P1_ControlGroup    0.002775
# 7           P0_ControlGroup    0.002716
